# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Olivia Lo
# * Student pace: part time 041519
# * Scheduled project review date/time: TBC
# * Instructor name: Victor
# * Blog post URL: TBC

# %%
# working with Pandas Dataframes throughout the project 
import pandas as pd
import numpy as np

# for data visualiazation
import seaborn as sns
from seaborn import lmplot

import statsmodels as sm

import matplotlib.pyplot as plt
from matplotlib.pyplot import show,figure,subplot
from matplotlib import dates as dates

# %%
# import the dataframe
df = pd.read_csv('kc_house_data.csv','r', delimiter=',')
df.head()
# Out:
#            id        date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  10/13/2014  221900         3       1.00         1180      5650
# 1  6414100192   12/9/2014  538000         3       2.25         2570      7242
# 2  5631500400   2/25/2015  180000         2       1.00          770     10000
# 3  2487200875   12/9/2014  604000         4       3.00         1960      5000
# 4  1954400510   2/18/2015  510000         3       2.00         1680      8080
#
#    floors  waterfront  view     ...      grade  sqft_above  sqft_basement  \
# 0     1.0         NaN   0.0     ...          7        1180              0
# 1     2.0         0.0   0.0     ...          7        2170            400
# 2     1.0         0.0   0.0     ...          6         770              0
# 3     1.0         0.0   0.0     ...          7        1050            910
# 4     1.0         0.0   0.0     ...          8        1680              0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
# to import column name descriptions included within project
from IPython.display import display, Markdown

# using Ipython.display to read and display different file  
# from project folder within this notebook
with open('column_names.md', 'r') as fh:
    content = fh.read()

display(Markdown(content))
# Out:
# # Column Names and descriptions for Kings County Data Set
# * **id** - unique identified for a house
# * **dateDate** - house was sold
# * **pricePrice** -  is prediction target
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  footage of the home
# * **sqft_lotsquare** -  footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %%
# to understand how many rows of data there are
print(len(df))
# Out:
# 21597

# %%
# to understand the datatype of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null int64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(7), int64(12), object(2)
# memory usage: 3.5+ MB

# %%
# replace missing value with 0 in view category
df['view'].fillna(0,inplace=True)
df['view'].isnull().sum()
# Out:
# 0

# %%
df['view'].value_counts()
# Out:
# 0    19485
# 2      957
# 3      508
# 1      330
# 4      317
# Name: view, dtype: int64

# %%
df['view'] = df['view'].astype(int)

# %%
# replace missing value with 0 in yr_renovated category
df['yr_renovated'].fillna(0,inplace=True)
df['yr_renovated'].isnull().sum()
# Out:
# 0

# %%
df['yr_renovated'].value_counts().head()
# Out:
# 0       20853
# 2014       73
# 2003       31
# 2013       31
# 2007       30
# Name: yr_renovated, dtype: int64

# %%
df['yr_renovated'] = df['yr_renovated'].astype(int)

# %%
# change waterfront into a boolean to show whether they have waterfront
df['waterfront'] = df['waterfront'].astype('bool')

# %%
df['waterfront'].value_counts().head()
# Out:
# False    19075
# True      2522
# Name: waterfront, dtype: int64

# %%
# remove question marks in sqft_basement 
df = df[df.sqft_basement != '?']
df['sqft_basement'].value_counts().head()
# Out:
# 0      12826
# 600      217
# 500      209
# 700      208
# 800      201
# Name: sqft_basement, dtype: int64

# %%
df['sqft_basement'] = df['sqft_basement'].astype(int)

# %%
# to check data type of each column after editing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21143 non-null int64
# date             21143 non-null object
# price            21143 non-null int64
# bedrooms         21143 non-null int64
# bathrooms        21143 non-null float64
# sqft_living      21143 non-null int64
# sqft_lot         21143 non-null int64
# floors           21143 non-null float64
# waterfront       21143 non-null bool
# view             21143 non-null int32
# condition        21143 non-null int64
# grade            21143 non-null int64
# sqft_above       21143 non-null int64
# sqft_basement    21143 non-null int32
# yr_built         21143 non-null int64
# yr_renovated     21143 non-null int32
# zipcode          21143 non-null int64
# lat              21143 non-null float64
# long             21143 non-null float64
# sqft_living15    21143 non-null int64
# sqft_lot15       21143 non-null int64
# dtypes: bool(1), float64(4), int32(3), int64(12), object(1)
# memory usage: 3.2+ MB

# %%
df.hist(figsize = (20,18))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     279     try:
# --> 280         dt = signed_to_unsigned[dt.type]
#     281     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5bb1446c71bf> in <module>()
# ----> 1 df.hist(figsize = (20,18))
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2411     for i, col in enumerate(com._try_sort(data.columns)):
#    2412         ax = _axes[i]
# -> 2413         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#    2414         ax.set_title(col)
#    2415         ax.grid(grid)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6637             # this will automatically overwrite bins,
#    6638             # so that each histogram uses the same bins
# -> 6639             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640             m = m.astype(float)  # causes problems later if it's an int
#    6641             if mlast is None:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     730
#     731         # Pre-compute histogram scaling factor
# --> 732         norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
#     733
#     734         # We iterate over blocks here for two reasons: the first is that for
#
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     280         dt = signed_to_unsigned[dt.type]
#     281     except KeyError:
# --> 282         return np.subtract(a, b, dtype=dt)
#     283     else:
#     284         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
for column in ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']:
    df[column].plot.hist(normed=True )
    df[column].plot.kde(label=column )
    plt.legend()
    plt.show()
# Out:
# C:\Users\Olivia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Olivia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Olivia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Olivia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Olivia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Olivia\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     279     try:
# --> 280         dt = signed_to_unsigned[dt.type]
#     281     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-aed7f8572e19> in <module>()
#       1 for column in ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']:
# ----> 2     df[column].plot.hist(normed=True )
#       3     df[column].plot.kde(label=column )
#       4     plt.legend()
#       5     plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, bins, **kwds)
#    2831         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2832         """
# -> 2833         return self(kind='hist', bins=bins, **kwds)
#    2834
#    2835     @Appender(_kde_docstring % {
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     255
#     256     def generate(self):
# --> 257         self._args_adjust()
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _args_adjust(self)
#    1327                 values, bins=self.bins,
#    1328                 range=self.kwds.get('range', None),
# -> 1329                 weights=self.kwds.get('weights', None))
#    1330
#    1331         if is_list_like(self.bottom):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     730
#     731         # Pre-compute histogram scaling factor
# --> 732         norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
#     733
#     734         # We iterate over blocks here for two reasons: the first is that for
#
# ~\Anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     280         dt = signed_to_unsigned[dt.type]
#     281     except KeyError:
# --> 282         return np.subtract(a, b, dtype=dt)
#     283     else:
#     284         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
# to group the dependent variables into kc_feature
kc_feature_names = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
kc_feature_df = df [kc_feature_names]

# %%
kc_feature_df.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0        True     0
# 1         3       2.25         2570      7242     2.0       False     0
# 2         2       1.00          770     10000     1.0       False     0
# 3         4       3.00         1960      5000     1.0       False     0
# 4         3       2.00         1680      8080     1.0       False     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062
# 3    98136  47.5208 -122.393           1360        5000
# 4    98074  47.6168 -122.045           1800        7503

# %%
# to group the independent variable into kc_price
kc_price_df = df ['price']

# %%
kc_price_df.head()
# Out:
# 0    221900
# 1    538000
# 2    180000
# 3    604000
# 4    510000
# Name: price, dtype: int64

# %%
# to form scatter plots of each dependent variable
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3))

for xcol, ax in zip(list(kc_feature_df)[0:5], axes):
    df.plot(kind='scatter', x= xcol, y="price", ax=ax, alpha=0.4, color='b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3))

for xcol, ax in zip(list(kc_feature_df)[6:10], axes):
    df.plot(kind='scatter', x= xcol, y="price", ax=ax, alpha=0.4, color='b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3))

for xcol, ax in zip(list(kc_feature_df)[10:14], axes):
    df.plot(kind='scatter', x= xcol, y="price", ax=ax, alpha=0.4, color='b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3))

for xcol, ax in zip(list(kc_feature_df)[14:18], axes):
    df.plot(kind='scatter', x= xcol, y="price", ax=ax, alpha=0.4, color='b')

# %%
# binning categorial data?? what should be categorical data? (i.e. objects in pandas)
# create dummy variables
# reimport dataframe with dummy variables
# scatter matrix
# correlation matrix and remove highly correlated variables
# reimport dataframe with dummy variables and without the highly correlated variables
# histograms for continuous variables
# perform log transformation
# run linear model in statsmodel and scikit-learn
